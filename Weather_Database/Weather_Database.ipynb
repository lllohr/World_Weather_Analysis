# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#Import OS
import os

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 789

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | cidreira
# Processing Record 4 of Set 1 | hambantota
# Processing Record 5 of Set 1 | cabra
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | pacific grove
# Processing Record 10 of Set 1 | westport
# Processing Record 11 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 1 | darnah
# Processing Record 13 of Set 1 | mae sai
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | klaksvik
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | okhotsk
# Processing Record 20 of Set 1 | saint-louis
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | tiksi
# Processing Record 23 of Set 1 | olafsvik
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | shelton
# Processing Record 27 of Set 1 | belyy yar
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | aktash
# Processing Record 31 of Set 1 | grand gaube
# Processing Record 32 of Set 1 | chuy
# Processing Record 33 of Set 1 | bengkulu
# Processing Record 34 of Set 1 | castro
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | upernavik
# Processing Record 37 of Set 1 | paamiut
# Processing Record 38 of Set 1 | la palma
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | lagoa
# Processing Record 43 of Set 1 | yanai
# Processing Record 44 of Set 1 | touros
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | krasnyy yar
# Processing Record 47 of Set 1 | pampa
# Processing Record 48 of Set 1 | alofi
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | harper
# Processing Record 1 of Set 2 | komarikhinskiy
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | zonguldak
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | erenhot
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | burgstadt
# Processing Record 10 of Set 2 | panlaitan
# Processing Record 11 of Set 2 | sur
# Processing Record 12 of Set 2 | chokurdakh
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | ishigaki
# Processing Record 15 of Set 2 | doha
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | brewster
# Processing Record 18 of Set 2 | natal
# Processing Record 19 of Set 2 | albany
# Processing Record 20 of Set 2 | obodivka
# Processing Record 21 of Set 2 | havoysund
# Processing Record 22 of Set 2 | izmit
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | brooks
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | jinzhou
# Processing Record 28 of Set 2 | sisimiut
# Processing Record 29 of Set 2 | carnarvon
# Processing Record 30 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 32 of Set 2 | barrow
# Processing Record 33 of Set 2 | boyolangu
# Processing Record 34 of Set 2 | catuday
# Processing Record 35 of Set 2 | orotukan
# Processing Record 36 of Set 2 | mildura
# Processing Record 37 of Set 2 | siddipet
# Processing Record 38 of Set 2 | lorengau
# Processing Record 39 of Set 2 | medvezhyegorsk
# Processing Record 40 of Set 2 | belmonte
# Processing Record 41 of Set 2 | manzhouli
# Processing Record 42 of Set 2 | flinders
# Processing Record 43 of Set 2 | bolshaya rechka
# Processing Record 44 of Set 2 | pangody
# Processing Record 45 of Set 2 | antofagasta
# Processing Record 46 of Set 2 | amapa
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | fortuna
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | khasan
# Processing Record 1 of Set 3 | torbay
# Processing Record 2 of Set 3 | acapulco
# Processing Record 3 of Set 3 | kismayo
# Processing Record 4 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | smithers
# Processing Record 7 of Set 3 | tungkang
# City not found. Skipping...
# Processing Record 8 of Set 3 | san jose
# Processing Record 9 of Set 3 | bireun
# Processing Record 10 of Set 3 | ranir bazar
# Processing Record 11 of Set 3 | koumra
# Processing Record 12 of Set 3 | new norfolk
# Processing Record 13 of Set 3 | bambanglipuro
# Processing Record 14 of Set 3 | sinjar
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | siderno
# Processing Record 22 of Set 3 | new albany
# Processing Record 23 of Set 3 | riyadh
# Processing Record 24 of Set 3 | vostok
# Processing Record 25 of Set 3 | batagay-alyta
# Processing Record 26 of Set 3 | arraial do cabo
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | cururupu
# Processing Record 29 of Set 3 | mar del plata
# Processing Record 30 of Set 3 | peniche
# Processing Record 31 of Set 3 | trelew
# Processing Record 32 of Set 3 | ust-nera
# Processing Record 33 of Set 3 | gaziantep
# Processing Record 34 of Set 3 | mitu
# Processing Record 35 of Set 3 | yuci
# Processing Record 36 of Set 3 | aketi
# Processing Record 37 of Set 3 | brae
# Processing Record 38 of Set 3 | vao
# Processing Record 39 of Set 3 | wadi musa
# Processing Record 40 of Set 3 | vasai
# Processing Record 41 of Set 3 | port elizabeth
# Processing Record 42 of Set 3 | parkhill
# Processing Record 43 of Set 3 | port shepstone
# Processing Record 44 of Set 3 | luban
# Processing Record 45 of Set 3 | sao filipe
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | husavik
# Processing Record 48 of Set 3 | cap malheureux
# Processing Record 49 of Set 3 | narsaq
# Processing Record 50 of Set 3 | te anau
# Processing Record 1 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 4 | hofn
# Processing Record 3 of Set 4 | rognedino
# Processing Record 4 of Set 4 | walvis bay
# Processing Record 5 of Set 4 | ucluelet
# Processing Record 6 of Set 4 | timra
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | hasaki
# Processing Record 9 of Set 4 | vaini
# Processing Record 10 of Set 4 | butwal
# Processing Record 11 of Set 4 | ilulissat
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | rawson
# Processing Record 15 of Set 4 | pontian kecil
# Processing Record 16 of Set 4 | gambela
# Processing Record 17 of Set 4 | unai
# Processing Record 18 of Set 4 | vangaindrano
# Processing Record 19 of Set 4 | kekri
# Processing Record 20 of Set 4 | galt
# Processing Record 21 of Set 4 | deputatskiy
# Processing Record 22 of Set 4 | ahipara
# Processing Record 23 of Set 4 | stepnyak
# Processing Record 24 of Set 4 | mount isa
# Processing Record 25 of Set 4 | talnakh
# Processing Record 26 of Set 4 | samarai
# Processing Record 27 of Set 4 | vilhena
# Processing Record 28 of Set 4 | inhambane
# Processing Record 29 of Set 4 | northam
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | umm kaddadah
# Processing Record 32 of Set 4 | aykhal
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | kruisfontein
# Processing Record 35 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 4 | datong
# Processing Record 37 of Set 4 | cairns
# Processing Record 38 of Set 4 | mackay
# Processing Record 39 of Set 4 | kavaratti
# Processing Record 40 of Set 4 | cherskiy
# Processing Record 41 of Set 4 | nerchinsk
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | cayenne
# Processing Record 44 of Set 4 | zlobin
# Processing Record 45 of Set 4 | wattegama
# Processing Record 46 of Set 4 | besancon
# Processing Record 47 of Set 4 | toora-khem
# Processing Record 48 of Set 4 | pevek
# Processing Record 49 of Set 4 | yumen
# Processing Record 50 of Set 4 | nuuk
# Processing Record 1 of Set 5 | mount gambier
# Processing Record 2 of Set 5 | geraldton
# Processing Record 3 of Set 5 | yerbogachen
# Processing Record 4 of Set 5 | rabo de peixe
# Processing Record 5 of Set 5 | nerchinskiy zavod
# Processing Record 6 of Set 5 | agadez
# Processing Record 7 of Set 5 | luz
# Processing Record 8 of Set 5 | ossora
# Processing Record 9 of Set 5 | cape town
# Processing Record 10 of Set 5 | cabo san lucas
# Processing Record 11 of Set 5 | borba
# Processing Record 12 of Set 5 | jumla
# Processing Record 13 of Set 5 | kuala terengganu
# Processing Record 14 of Set 5 | burbank
# Processing Record 15 of Set 5 | itoman
# Processing Record 16 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 5 | kemijarvi
# Processing Record 18 of Set 5 | la ronge
# Processing Record 19 of Set 5 | krasnoselkup
# Processing Record 20 of Set 5 | inta
# Processing Record 21 of Set 5 | plouzane
# Processing Record 22 of Set 5 | mahebourg
# Processing Record 23 of Set 5 | fairbanks
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | nalut
# Processing Record 26 of Set 5 | leningradskiy
# Processing Record 27 of Set 5 | hammerfest
# Processing Record 28 of Set 5 | beringovskiy
# Processing Record 29 of Set 5 | port hedland
# Processing Record 30 of Set 5 | motygino
# Processing Record 31 of Set 5 | nanortalik
# Processing Record 32 of Set 5 | kitsuki
# Processing Record 33 of Set 5 | clyde river
# Processing Record 34 of Set 5 | srednekolymsk
# Processing Record 35 of Set 5 | pitimbu
# Processing Record 36 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 5 | tautira
# Processing Record 38 of Set 5 | saint george
# Processing Record 39 of Set 5 | nome
# Processing Record 40 of Set 5 | merauke
# Processing Record 41 of Set 5 | grand island
# Processing Record 42 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 5 | byron bay
# Processing Record 44 of Set 5 | codrington
# Processing Record 45 of Set 5 | teknaf
# Processing Record 46 of Set 5 | ahtopol
# Processing Record 47 of Set 5 | jalu
# Processing Record 48 of Set 5 | ciudad bolivar
# Processing Record 49 of Set 5 | kailua
# Processing Record 50 of Set 5 | guane
# Processing Record 1 of Set 6 | purranque
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | muros
# Processing Record 4 of Set 6 | tanabe
# Processing Record 5 of Set 6 | huangnihe
# Processing Record 6 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 6 | phalaborwa
# Processing Record 8 of Set 6 | yulara
# Processing Record 9 of Set 6 | baracoa
# Processing Record 10 of Set 6 | honiara
# Processing Record 11 of Set 6 | acari
# Processing Record 12 of Set 6 | karratha
# Processing Record 13 of Set 6 | russell
# Processing Record 14 of Set 6 | isangel
# Processing Record 15 of Set 6 | airai
# Processing Record 16 of Set 6 | praia
# Processing Record 17 of Set 6 | faanui
# Processing Record 18 of Set 6 | wanaka
# Processing Record 19 of Set 6 | chingirlau
# Processing Record 20 of Set 6 | ennis
# Processing Record 21 of Set 6 | tuatapere
# Processing Record 22 of Set 6 | camopi
# Processing Record 23 of Set 6 | kaminskiy
# Processing Record 24 of Set 6 | carballo
# Processing Record 25 of Set 6 | berlevag
# Processing Record 26 of Set 6 | biltine
# Processing Record 27 of Set 6 | fort frances
# Processing Record 28 of Set 6 | ostrovnoy
# Processing Record 29 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 6 | mao
# Processing Record 31 of Set 6 | kanelovskaya
# Processing Record 32 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 6 | gamba
# Processing Record 34 of Set 6 | ondjiva
# Processing Record 35 of Set 6 | saint-michel-des-saints
# Processing Record 36 of Set 6 | talara
# Processing Record 37 of Set 6 | gilazi
# City not found. Skipping...
# Processing Record 38 of Set 6 | high rock
# Processing Record 39 of Set 6 | cartagena
# Processing Record 40 of Set 6 | lompoc
# Processing Record 41 of Set 6 | miyazu
# Processing Record 42 of Set 6 | saint-augustin
# Processing Record 43 of Set 6 | souillac
# Processing Record 44 of Set 6 | pangkalanbuun
# Processing Record 45 of Set 6 | slave lake
# Processing Record 46 of Set 6 | coolum beach
# Processing Record 47 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 6 | masallatah
# Processing Record 49 of Set 6 | ariquemes
# Processing Record 50 of Set 6 | bilma
# Processing Record 1 of Set 7 | waipawa
# Processing Record 2 of Set 7 | takaka
# Processing Record 3 of Set 7 | petit goave
# Processing Record 4 of Set 7 | pattani
# Processing Record 5 of Set 7 | pisco
# Processing Record 6 of Set 7 | cabedelo
# Processing Record 7 of Set 7 | teacapan
# Processing Record 8 of Set 7 | crotone
# Processing Record 9 of Set 7 | alto araguaia
# Processing Record 10 of Set 7 | tazovskiy
# Processing Record 11 of Set 7 | ixtapa
# Processing Record 12 of Set 7 | christchurch
# Processing Record 13 of Set 7 | katsuura
# Processing Record 14 of Set 7 | tucuman
# Processing Record 15 of Set 7 | gat
# Processing Record 16 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 7 | burns lake
# Processing Record 18 of Set 7 | camalu
# Processing Record 19 of Set 7 | san andres
# Processing Record 20 of Set 7 | nushki
# Processing Record 21 of Set 7 | palu
# Processing Record 22 of Set 7 | norman wells
# Processing Record 23 of Set 7 | nabisar
# Processing Record 24 of Set 7 | akureyri
# Processing Record 25 of Set 7 | marystown
# Processing Record 26 of Set 7 | coihaique
# Processing Record 27 of Set 7 | banda aceh
# Processing Record 28 of Set 7 | lavrentiya
# Processing Record 29 of Set 7 | menongue
# Processing Record 30 of Set 7 | grindavik
# Processing Record 31 of Set 7 | chicama
# Processing Record 32 of Set 7 | mapiri
# Processing Record 33 of Set 7 | kavieng
# Processing Record 34 of Set 7 | kirgiz-miyaki
# Processing Record 35 of Set 7 | denpasar
# Processing Record 36 of Set 7 | sulangan
# Processing Record 37 of Set 7 | dole
# Processing Record 38 of Set 7 | meiganga
# Processing Record 39 of Set 7 | general roca
# Processing Record 40 of Set 7 | alzamay
# Processing Record 41 of Set 7 | poso
# Processing Record 42 of Set 7 | yining
# Processing Record 43 of Set 7 | broken hill
# Processing Record 44 of Set 7 | margate
# Processing Record 45 of Set 7 | alice springs
# Processing Record 46 of Set 7 | cibitoke
# Processing Record 47 of Set 7 | guiratinga
# Processing Record 48 of Set 7 | east cleveland
# Processing Record 49 of Set 7 | vestmannaeyjar
# Processing Record 50 of Set 7 | qingdao
# Processing Record 1 of Set 8 | mecca
# Processing Record 2 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 3 of Set 8 | ola
# Processing Record 4 of Set 8 | namibe
# Processing Record 5 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 8 | urucui
# Processing Record 7 of Set 8 | kendari
# Processing Record 8 of Set 8 | uk
# City not found. Skipping...
# Processing Record 9 of Set 8 | constitucion
# Processing Record 10 of Set 8 | tonekabon
# Processing Record 11 of Set 8 | santa ana
# Processing Record 12 of Set 8 | bandarbeyla
# Processing Record 13 of Set 8 | svetlyy
# Processing Record 14 of Set 8 | williston
# Processing Record 15 of Set 8 | pecos
# Processing Record 16 of Set 8 | tarnogskiy gorodok
# Processing Record 17 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 8 | qui nhon
# Processing Record 19 of Set 8 | najran
# Processing Record 20 of Set 8 | awjilah
# Processing Record 21 of Set 8 | medea
# Processing Record 22 of Set 8 | shimoda
# Processing Record 23 of Set 8 | kodiak
# Processing Record 24 of Set 8 | oktyabrskiy
# Processing Record 25 of Set 8 | masty
# Processing Record 26 of Set 8 | karatau
# Processing Record 27 of Set 8 | riachao
# Processing Record 28 of Set 8 | verkhnedneprovskiy
# Processing Record 29 of Set 8 | sal rei
# Processing Record 30 of Set 8 | yerofey pavlovich
# Processing Record 31 of Set 8 | althofen
# Processing Record 32 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 8 | chuguyevka
# Processing Record 34 of Set 8 | lata
# Processing Record 35 of Set 8 | paita
# Processing Record 36 of Set 8 | adigeni
# Processing Record 37 of Set 8 | aksarka
# Processing Record 38 of Set 8 | buenos aires
# Processing Record 39 of Set 8 | rosario
# Processing Record 40 of Set 8 | port macquarie
# Processing Record 41 of Set 8 | shingu
# Processing Record 42 of Set 8 | tarpon springs
# Processing Record 43 of Set 8 | mnogovershinnyy
# Processing Record 44 of Set 8 | pandan
# Processing Record 45 of Set 8 | abha
# Processing Record 46 of Set 8 | padang
# Processing Record 47 of Set 8 | hilpoltstein
# Processing Record 48 of Set 8 | tabas
# Processing Record 49 of Set 8 | jati
# Processing Record 50 of Set 8 | luganville
# Processing Record 1 of Set 9 | seoul
# Processing Record 2 of Set 9 | susehri
# Processing Record 3 of Set 9 | ipojuca
# Processing Record 4 of Set 9 | labuhan
# Processing Record 5 of Set 9 | zhigalovo
# Processing Record 6 of Set 9 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 7 of Set 9 | ornskoldsvik
# Processing Record 8 of Set 9 | maceio
# Processing Record 9 of Set 9 | tambopata
# Processing Record 10 of Set 9 | bowling green
# Processing Record 11 of Set 9 | lima
# Processing Record 12 of Set 9 | nikolskoye
# Processing Record 13 of Set 9 | tawau
# Processing Record 14 of Set 9 | djambala
# Processing Record 15 of Set 9 | padina
# Processing Record 16 of Set 9 | tromso
# Processing Record 17 of Set 9 | murgab
# Processing Record 18 of Set 9 | jiaozuo
# Processing Record 19 of Set 9 | baruun-urt
# Processing Record 20 of Set 9 | mandalgovi
# Processing Record 21 of Set 9 | benguela
# Processing Record 22 of Set 9 | yar-sale
# Processing Record 23 of Set 9 | auki
# Processing Record 24 of Set 9 | blairmore
# Processing Record 25 of Set 9 | shaunavon
# Processing Record 26 of Set 9 | afyonkarahisar
# Processing Record 27 of Set 9 | naron
# Processing Record 28 of Set 9 | santa
# Processing Record 29 of Set 9 | ati
# Processing Record 30 of Set 9 | izumo
# Processing Record 31 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 9 | dongli
# Processing Record 33 of Set 9 | perehonivka
# Processing Record 34 of Set 9 | moussoro
# Processing Record 35 of Set 9 | gravdal
# Processing Record 36 of Set 9 | corner brook
# Processing Record 37 of Set 9 | broome
# Processing Record 38 of Set 9 | manaus
# Processing Record 39 of Set 9 | yanam
# Processing Record 40 of Set 9 | manacapuru
# Processing Record 41 of Set 9 | lazaro cardenas
# Processing Record 42 of Set 9 | cockburn town
# Processing Record 43 of Set 9 | vila
# Processing Record 44 of Set 9 | weligama
# Processing Record 45 of Set 9 | college
# Processing Record 46 of Set 9 | san martin de hidalgo
# City not found. Skipping...
# Processing Record 47 of Set 9 | saldanha
# Processing Record 48 of Set 9 | sola
# Processing Record 49 of Set 9 | kalmunai
# Processing Record 50 of Set 9 | mafinga
# Processing Record 1 of Set 10 | rosa zarate
# Processing Record 2 of Set 10 | tsabong
# Processing Record 3 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 10 | esperance
# Processing Record 6 of Set 10 | laela
# Processing Record 7 of Set 10 | muyezerskiy
# Processing Record 8 of Set 10 | kuchinarai
# Processing Record 9 of Set 10 | gbarnga
# Processing Record 10 of Set 10 | tricase
# Processing Record 11 of Set 10 | mahibadhoo
# Processing Record 12 of Set 10 | caconda
# Processing Record 13 of Set 10 | hamilton
# Processing Record 14 of Set 10 | lerwick
# Processing Record 15 of Set 10 | yangshan
# Processing Record 16 of Set 10 | lithgow
# Processing Record 17 of Set 10 | portland
# Processing Record 18 of Set 10 | ambilobe
# Processing Record 19 of Set 10 | matara
# Processing Record 20 of Set 10 | tecpan
# Processing Record 21 of Set 10 | nizhniy tsasuchey
# Processing Record 22 of Set 10 | sarhari
# Processing Record 23 of Set 10 | kouango
# Processing Record 24 of Set 10 | makakilo city
# Processing Record 25 of Set 10 | olga
# Processing Record 26 of Set 10 | saint-joseph
# Processing Record 27 of Set 10 | palmer
# Processing Record 28 of Set 10 | svetlogorsk
# Processing Record 29 of Set 10 | avera
# Processing Record 30 of Set 10 | wawa
# Processing Record 31 of Set 10 | hay river
# Processing Record 32 of Set 10 | shakawe
# Processing Record 33 of Set 10 | charters towers
# Processing Record 34 of Set 10 | saint-francois
# Processing Record 35 of Set 10 | agirish
# Processing Record 36 of Set 10 | katete
# Processing Record 37 of Set 10 | inuvik
# Processing Record 38 of Set 10 | pacifica
# Processing Record 39 of Set 10 | san policarpo
# Processing Record 40 of Set 10 | houma
# Processing Record 41 of Set 10 | boa vista
# Processing Record 42 of Set 10 | bessonovka
# Processing Record 43 of Set 10 | cavalcante
# Processing Record 44 of Set 10 | poya
# Processing Record 45 of Set 10 | aksu
# Processing Record 46 of Set 10 | jalingo
# Processing Record 47 of Set 10 | bend
# Processing Record 48 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 10 | la antigua
# Processing Record 50 of Set 10 | dunda
# Processing Record 1 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 11 | nacala
# Processing Record 3 of Set 11 | jinchang
# Processing Record 4 of Set 11 | san quintin
# Processing Record 5 of Set 11 | logstor
# Processing Record 6 of Set 11 | moron
# Processing Record 7 of Set 11 | zharkent
# Processing Record 8 of Set 11 | camacha
# Processing Record 9 of Set 11 | zahirabad
# Processing Record 10 of Set 11 | verkhnyaya inta
# Processing Record 11 of Set 11 | kautokeino
# Processing Record 12 of Set 11 | homer
# Processing Record 13 of Set 11 | dingle
# Processing Record 14 of Set 11 | kalyazin
# Processing Record 15 of Set 11 | yalvac
# Processing Record 16 of Set 11 | saint-pierre
# Processing Record 17 of Set 11 | leua
# Processing Record 18 of Set 11 | dmytrivka
# Processing Record 19 of Set 11 | vale
# Processing Record 20 of Set 11 | tsuruoka
# Processing Record 21 of Set 11 | meulaboh
# Processing Record 22 of Set 11 | dauphin
# Processing Record 23 of Set 11 | oranjemund
# Processing Record 24 of Set 11 | sorland
# Processing Record 25 of Set 11 | maniitsoq
# Processing Record 26 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 11 | mhango
# Processing Record 28 of Set 11 | jardim
# Processing Record 29 of Set 11 | kant
# Processing Record 30 of Set 11 | sangar
# Processing Record 31 of Set 11 | sobolevo
# Processing Record 32 of Set 11 | kaniv
# Processing Record 33 of Set 11 | ewa beach
# Processing Record 34 of Set 11 | sao felix do xingu
# Processing Record 35 of Set 11 | iesolo
# Processing Record 36 of Set 11 | fort nelson
# Processing Record 37 of Set 11 | rach gia
# Processing Record 38 of Set 11 | ningan
# City not found. Skipping...
# Processing Record 39 of Set 11 | guangshui
# Processing Record 40 of Set 11 | tchollire
# Processing Record 41 of Set 11 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 42 of Set 11 | oistins
# Processing Record 43 of Set 11 | kahului
# Processing Record 44 of Set 11 | novyy urgal
# Processing Record 45 of Set 11 | kodinsk
# Processing Record 46 of Set 11 | vila velha
# Processing Record 47 of Set 11 | naze
# Processing Record 48 of Set 11 | taua
# Processing Record 49 of Set 11 | ganzhou
# Processing Record 50 of Set 11 | pervomayskoye
# Processing Record 1 of Set 12 | chitral
# Processing Record 2 of Set 12 | barra do garcas
# Processing Record 3 of Set 12 | flagstaff
# Processing Record 4 of Set 12 | kochi
# Processing Record 5 of Set 12 | gopalpur
# Processing Record 6 of Set 12 | tarakan
# Processing Record 7 of Set 12 | santarem
# Processing Record 8 of Set 12 | dilla
# Processing Record 9 of Set 12 | ust-tsilma
# Processing Record 10 of Set 12 | el tocuyo
# Processing Record 11 of Set 12 | leh
# Processing Record 12 of Set 12 | manavadar
# Processing Record 13 of Set 12 | faya
# Processing Record 14 of Set 12 | pundaguitan
# Processing Record 15 of Set 12 | evensk
# Processing Record 16 of Set 12 | taoudenni
# Processing Record 17 of Set 12 | kidal
# Processing Record 18 of Set 12 | jodar
# Processing Record 19 of Set 12 | khorramabad
# Processing Record 20 of Set 12 | vardo
# Processing Record 21 of Set 12 | newport
# Processing Record 22 of Set 12 | mehamn
# Processing Record 23 of Set 12 | vrangel
# Processing Record 24 of Set 12 | langsa
# Processing Record 25 of Set 12 | methoni
# Processing Record 26 of Set 12 | kawalu
# Processing Record 27 of Set 12 | kalabo
# Processing Record 28 of Set 12 | tianpeng
# Processing Record 29 of Set 12 | tsentralnyy
# City not found. Skipping...
# Processing Record 30 of Set 12 | mutoko
# Processing Record 31 of Set 12 | eunice
# Processing Record 32 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 33 of Set 12 | qasigiannguit
# Processing Record 34 of Set 12 | salinopolis
# Processing Record 35 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 36 of Set 12 | toktogul
# Processing Record 37 of Set 12 | pitsunda
# Processing Record 38 of Set 12 | cap-aux-meules
# Processing Record 39 of Set 12 | kedrovyy
# Processing Record 40 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 12 | lasa
# Processing Record 42 of Set 12 | nemuro
# Processing Record 43 of Set 12 | srandakan
# Processing Record 44 of Set 12 | point pedro
# Processing Record 45 of Set 12 | iralaya
# Processing Record 46 of Set 12 | beverwijk
# Processing Record 47 of Set 12 | sakakah
# Processing Record 48 of Set 12 | noumea
# Processing Record 49 of Set 12 | esmeraldas
# Processing Record 50 of Set 12 | bagotville
# Processing Record 1 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 13 | kjollefjord
# Processing Record 3 of Set 13 | ardakan
# Processing Record 4 of Set 13 | esso
# Processing Record 5 of Set 13 | otradnoye
# Processing Record 6 of Set 13 | bojaya
# City not found. Skipping...
# Processing Record 7 of Set 13 | kyrylivka
# Processing Record 8 of Set 13 | orlik
# Processing Record 9 of Set 13 | salinas
# Processing Record 10 of Set 13 | mirabad
# Processing Record 11 of Set 13 | atar
# Processing Record 12 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 13 | ngama
# Processing Record 14 of Set 13 | somerset
# Processing Record 15 of Set 13 | anadyr
# Processing Record 16 of Set 13 | coquimbo
# Processing Record 17 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 13 | kuryk
# Processing Record 19 of Set 13 | drochia
# Processing Record 20 of Set 13 | tazmalt
# Processing Record 21 of Set 13 | vanimo
# Processing Record 22 of Set 13 | abu dhabi
# Processing Record 23 of Set 13 | eyl
# Processing Record 24 of Set 13 | mashhad
# Processing Record 25 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 13 | ankang
# Processing Record 27 of Set 13 | sao miguel do araguaia
# Processing Record 28 of Set 13 | stekolnyy
# City not found. Skipping...
# Processing Record 29 of Set 13 | sinnamary
# Processing Record 30 of Set 13 | ekibastuz
# Processing Record 31 of Set 13 | lesogorskiy
# Processing Record 32 of Set 13 | ayan
# Processing Record 33 of Set 13 | berezanka
# Processing Record 34 of Set 13 | yuli
# Processing Record 35 of Set 13 | stornoway
# Processing Record 36 of Set 13 | alta floresta
# Processing Record 37 of Set 13 | skelleftea
# Processing Record 38 of Set 13 | ancud
# Processing Record 39 of Set 13 | marquette
# Processing Record 40 of Set 13 | westerland
# Processing Record 41 of Set 13 | winnemucca
# Processing Record 42 of Set 13 | bud
# Processing Record 43 of Set 13 | half moon bay
# Processing Record 44 of Set 13 | altus
# Processing Record 45 of Set 13 | kabompo
# Processing Record 46 of Set 13 | jaunpur
# Processing Record 47 of Set 13 | kulhudhuffushi
# Processing Record 48 of Set 13 | makow mazowiecki
# Processing Record 49 of Set 13 | ayer molek
# Processing Record 50 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 14 | treinta y tres
# Processing Record 2 of Set 14 | prachuap khiri khan
# Processing Record 3 of Set 14 | sitka
# Processing Record 4 of Set 14 | saint anthony
# Processing Record 5 of Set 14 | usinsk
# Processing Record 6 of Set 14 | ebebiyin
# Processing Record 7 of Set 14 | male
# Processing Record 8 of Set 14 | jiayuguan
# Processing Record 9 of Set 14 | zhigansk
# Processing Record 10 of Set 14 | mirnyy
# Processing Record 11 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 14 | huntingdon
# Processing Record 13 of Set 14 | diffa
# Processing Record 14 of Set 14 | nakatsugawa
# Processing Record 15 of Set 14 | adrar
# Processing Record 16 of Set 14 | miri
# Processing Record 17 of Set 14 | ojinaga
# Processing Record 18 of Set 14 | sinazongwe
# Processing Record 19 of Set 14 | angoche
# Processing Record 20 of Set 14 | kurilsk
# Processing Record 21 of Set 14 | asyut
# Processing Record 22 of Set 14 | san vicente
# Processing Record 23 of Set 14 | dicabisagan
# Processing Record 24 of Set 14 | zaqatala
# Processing Record 25 of Set 14 | colorado springs
# Processing Record 26 of Set 14 | dunmore east
# Processing Record 27 of Set 14 | forio
# Processing Record 28 of Set 14 | helena
# Processing Record 29 of Set 14 | dabakala
# Processing Record 30 of Set 14 | viedma
# Processing Record 31 of Set 14 | lambarene
# Processing Record 32 of Set 14 | sept-iles
# Processing Record 33 of Set 14 | luanda
# Processing Record 34 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 35 of Set 14 | mlonggo
# Processing Record 36 of Set 14 | axim
# Processing Record 37 of Set 14 | korhogo
# Processing Record 38 of Set 14 | ruidoso
# Processing Record 39 of Set 14 | aracruz
# Processing Record 40 of Set 14 | nata
# Processing Record 41 of Set 14 | kamina
# Processing Record 42 of Set 14 | hami
# Processing Record 43 of Set 14 | andes
# Processing Record 44 of Set 14 | hervey bay
# Processing Record 45 of Set 14 | kapuskasing
# Processing Record 46 of Set 14 | rosetown
# Processing Record 47 of Set 14 | rio grande
# Processing Record 48 of Set 14 | henties bay
# Processing Record 49 of Set 14 | nouadhibou
# Processing Record 50 of Set 14 | santa rosa
# Processing Record 1 of Set 15 | biskamzha
# Processing Record 2 of Set 15 | finschhafen
# Processing Record 3 of Set 15 | marzuq
# Processing Record 4 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 15 | puerto escondido
# Processing Record 6 of Set 15 | port hardy
# Processing Record 7 of Set 15 | batouri
# Processing Record 8 of Set 15 | plettenberg bay
# Processing Record 9 of Set 15 | paragominas
# Processing Record 10 of Set 15 | birin
# Processing Record 11 of Set 15 | tahara
# Processing Record 12 of Set 15 | inongo
# Processing Record 13 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 14 of Set 15 | kedgwick
# Processing Record 15 of Set 15 | santa isabel do rio negro
# Processing Record 16 of Set 15 | oktyabrskoye
# Processing Record 17 of Set 15 | ust-tarka
# Processing Record 18 of Set 15 | erdenet
# Processing Record 19 of Set 15 | wexford
# Processing Record 20 of Set 15 | marawi
# Processing Record 21 of Set 15 | prata
# Processing Record 22 of Set 15 | itaberaba
# Processing Record 23 of Set 15 | mana
# Processing Record 24 of Set 15 | san patricio
# Processing Record 25 of Set 15 | irtyshskiy
# Processing Record 26 of Set 15 | atambua
# Processing Record 27 of Set 15 | muroto
# Processing Record 28 of Set 15 | casper
# Processing Record 29 of Set 15 | ketchikan
# Processing Record 30 of Set 15 | astoria
# Processing Record 31 of Set 15 | namikupa
# Processing Record 32 of Set 15 | sambava
# Processing Record 33 of Set 15 | kentau
# Processing Record 34 of Set 15 | manggar
# Processing Record 35 of Set 15 | launceston
# Processing Record 36 of Set 15 | eruwa
# Processing Record 37 of Set 15 | huarmey
# Processing Record 38 of Set 15 | mpika
# Processing Record 39 of Set 15 | caravelas
# Processing Record 40 of Set 15 | bathsheba
# Processing Record 41 of Set 15 | wau
# Processing Record 42 of Set 15 | araouane
# Processing Record 43 of Set 15 | bonito
# Processing Record 44 of Set 15 | planeta rica
# Processing Record 45 of Set 15 | wainwright
# Processing Record 46 of Set 15 | clearwater
# Processing Record 47 of Set 15 | baijiantan
# Processing Record 48 of Set 15 | bansi
# Processing Record 49 of Set 15 | eureka
# Processing Record 50 of Set 15 | siilinjarvi
# Processing Record 1 of Set 16 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 16 | morehead
# Processing Record 3 of Set 16 | port hawkesbury
# Processing Record 4 of Set 16 | limon
# Processing Record 5 of Set 16 | caxito
# Processing Record 6 of Set 16 | talcahuano
# Processing Record 7 of Set 16 | ekhabi
# Processing Record 8 of Set 16 | san isidro
# Processing Record 9 of Set 16 | gurskoye
# City not found. Skipping...
# Processing Record 10 of Set 16 | roswell
# Processing Record 11 of Set 16 | lewisporte
# Processing Record 12 of Set 16 | chipoka
# Processing Record 13 of Set 16 | kupang
# Processing Record 14 of Set 16 | kabanjahe
# Processing Record 15 of Set 16 | port augusta
# Processing Record 16 of Set 16 | boende
# Processing Record 17 of Set 16 | taft
# Processing Record 18 of Set 16 | lavumisa
# Processing Record 19 of Set 16 | osinovo
# Processing Record 20 of Set 16 | nador
# Processing Record 21 of Set 16 | vagur
# Processing Record 22 of Set 16 | west bay
# Processing Record 23 of Set 16 | tual
# Processing Record 24 of Set 16 | masterton
# Processing Record 25 of Set 16 | luwuk
# Processing Record 26 of Set 16 | akyab
# Processing Record 27 of Set 16 | chapais
# Processing Record 28 of Set 16 | termiz
# Processing Record 29 of Set 16 | sarankhola
# Processing Record 30 of Set 16 | nhulunbuy
# Processing Record 31 of Set 16 | kattivakkam
# Processing Record 32 of Set 16 | nuevo progreso
# Processing Record 33 of Set 16 | roma
# Processing Record 34 of Set 16 | salina
# Processing Record 35 of Set 16 | kokoda
# Processing Record 36 of Set 16 | san marcos
# Processing Record 37 of Set 16 | salalah
# Processing Record 38 of Set 16 | sechura
# Processing Record 39 of Set 16 | arrecife
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Bluff      NZ -46.6000  168.3333     59.70        74           8
# 1    Yellowknife      CA  62.4560 -114.3525     17.42        58          20
# 2       Cidreira      BR -30.1811  -50.2056     69.26        81           0
# 3     Hambantota      LK   6.1241   81.1185     77.61        87          14
# 4          Cabra      ES  37.4725   -4.4421     55.65        72          98
# 5         Dikson      RU  73.5069   80.5464    -18.04       100          26
# 6        Rikitea      PF -23.1203 -134.9692     79.18        65          27
# 7  Pacific Grove      US  36.6177 -121.9166     64.58        64          86
# 8       Westport      US  41.1415  -73.3579     38.89        57         100
# 9         Darnah      LY  32.7670   22.6367     58.48        61          87
#
#    Wind Speed Current Description
# 0        2.82           clear sky
# 1        3.44          few clouds
# 2        8.75           clear sky
# 3        5.75          few clouds
# 4        3.69     overcast clouds
# 5        3.71    scattered clouds
# 6        8.81    scattered clouds
# 7       21.99     overcast clouds
# 8       13.00     overcast clouds
# 9       12.48     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
